# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from itertools import chain
from collections import Counter

# %%
df = pd.read_csv('naukri_data.csv')

# %%
df
# Out:
#                                             job_title  \
# 0                     Data Analyst (0-2yrs) Bangalore
# 1                                 French Data Analyst
# 2                                        Data Analyst
# 3    Business Analyst/ Software Analyst/ Data Analyst
# 4                                     HR Data Analyst
# ..                                                ...
# 962                                      Data Analyst
# 963                                      Data Analyst
# 964                                    Data Analyst I
# 965                                      Data Analyst
# 966                                 Lead Data Analyst
#
#                    company_name    experience                      salary  \
# 0              Gupta And Sharma   0 - 2 years  ₹ 3,50,000 - 6,00,000 P.A.
# 1                      Randstad   0 - 1 years  ₹ 2,50,000 - 3,50,000 P.A.
# 2                Namdhari Seeds   0 - 2 years               Not Disclosed
# 3                    Optiontown   0 - 2 years  ₹ 4,00,000 - 7,00,000 P.A.
# 4                       Walmart   2 - 5 years               Not Disclosed
# ..                          ...           ...                         ...
# 962  Capital Placement Services   2 - 4 years               Not Disclosed
# 963      The Education Alliance   2 - 4 years               Not Disclosed
# 964            Venator Holdings   2 - 4 years               Not Disclosed
# 965        TN Business Services   2 - 5 years               Not Disclosed
# 966               Pocket Worlds  5 - 10 years               Not Disclosed
#
#                    location  \
# 0       Bangalore/Bengaluru
# 1                       PAN
# 2       Bangalore/Bengaluru
# 3                     Delhi
# 4       Bangalore/Bengaluru
# ..                      ...
# 962                   Delhi
# 963                 Chennai
# 964  Hyderabad/Secunderabad
# 965        Gurgaon/Gurugram
# 966                  Remote
#
#                                        job_description  \
# 0    Roles and Responsibilities\nAcquiring data fro...
# 1    Roles and Responsibilities\n\nJob Description:...
# 2    Roles and Responsibilities\nCreate and validat...
# 3    Analysts will leverage analytic, quantitative ...
# 4    Data Analyst - TA Position summary:\nDemonstra...
# ..                                                 ...
# 962  Expertise in analysing data and creating innov...
# 963  Interested in starting or advancing an early c...
# 964  Key Responsibilities:\nPerform detailed data a...
# 965  - Using automated tools to extract data from p...
# 966  This role will give you the opportunity to...\...
#
#                               role  \
# 0                     Data Analyst
# 1                     Data Analyst
# 2                            Other
# 3                 Business Analyst
# 4                       HR Analyst
# ..                             ...
# 962               Business Analyst
# 963                   Data Analyst
# 964  Database Architect / Designer
# 965                   Data Analyst
# 966                   Data Analyst
#
#                                      industry_type  \
# 0                                          Banking
# 1                         IT Services & Consulting
# 2                 Agriculture / Forestry / Fishing
# 3                                         Aviation
# 4                                 Software Product
# ..                                             ...
# 962                         Recruitment / Staffing
# 963  NGO / Social Services / Industry Associations
# 964                       IT Services & Consulting
# 965                          Management Consulting
# 966                                       Internet
#
#                       department                   employment_type  \
# 0       Data Science & Analytics              Full Time, Permanent
# 1       Data Science & Analytics              Full Time, Permanent
# 2                          Other              Full Time, Permanent
# 3       Data Science & Analytics              Full Time, Permanent
# 4                Human Resources  Full Time, Temporary/Contractual
# ..                           ...                               ...
# 962     Data Science & Analytics              Full Time, Permanent
# 963     Data Science & Analytics              Full Time, Permanent
# 964  Engineering - Software & QA              Full Time, Permanent
# 965     Data Science & Analytics              Full Time, Permanent
# 966     Data Science & Analytics              Full Time, Permanent
#
#                          role_category  \
# 0    Business Intelligence & Analytics
# 1    Business Intelligence & Analytics
# 2                                Other
# 3    Business Intelligence & Analytics
# 4                        HR Operations
# ..                                 ...
# 962  Business Intelligence & Analytics
# 963  Business Intelligence & Analytics
# 964             DBA / Data warehousing
# 965  Business Intelligence & Analytics
# 966  Business Intelligence & Analytics
#
#                                              education  \
# 0    B.Tech/B.E. in Computers, B.Sc in Computers, B...
# 1                                         Any Graduate
# 2                       MBA/PGDM in Any Specialization
# 3                    B.Tech/B.E. in Any Specialization
# 4                                         Any Graduate
# ..                                                 ...
# 962               B.Tech/B.E. in Production/Industrial
# 963                                       Any Graduate
# 964                                       Any Graduate
# 965               B.Tech/B.E. in Production/Industrial
# 966                                       Any Graduate
#
#                                             key_skills    date_posted  \
# 0    ['plsql', 'excel', 'data analysis', 'sas', 'or...      1 day ago
# 1         ['Bi-lingual French', 'French Data Analyst']      1 day ago
# 2    ['supply chain operations', 'data analytics', ...    13 days ago
# 3    ['Analysis', 'Predictive Modeling', 'Requireme...      1 day ago
# 4    ['Excel Report Preparation', 'excel', 'data an...  Few Hours Ago
# ..                                                 ...            ...
# 962  ['Computer science', 'Data analysis', 'Excel',...   30+ days ago
# 963  ['Root cause analysis', 'Data analysis', 'Inte...   30+ days ago
# 964  ['Computer science', 'Data analysis', 'metadat...   30+ days ago
# 965  ['Data analysis', 'Coding', 'Database design',...   30+ days ago
# 966  ['Data analysis', 'Analytical', 'Machine learn...   30+ days ago
#
#      num_openings  num_applicants experience_bins
# 0             3.0            2647             0-2
# 1             NaN             145             0-2
# 2             NaN            8751             0-2
# 3             NaN            1358             0-2
# 4             NaN              50             2-5
# ..            ...             ...             ...
# 962           1.0            1430             2-5
# 963           1.0             628             2-5
# 964           1.0             110             2-5
# 965           1.0             247             2-5
# 966           1.0              61            5-12
#
# [967 rows x 17 columns]

# %%
# experience bar graph
plt.figure(figsize=(12, 6))
sns.countplot(data=df, x='experience_bins')
plt.title("Job posting divided by experience")
plt.xlabel('Experience');

# %%
# role bar graph
plt.figure(figsize=(12, 6))

value_counts = df['role'].value_counts()

# Get the top 15 values
top_15 = value_counts[:15]

# Plot the top 15 values
sns.countplot(data=df, y='role', order=top_15.index, orient='h')
plt.title("Job posting divided by role")
plt.ylabel('Role');

# %%
import ast

# Get a list of the items in each row
skills_per_row = [ast.literal_eval(items) for items in df['key_skills']]

# Flatten the list of lists into a single list
skills = [item for sublist in skills_per_row for item in sublist]

most_common_skills = Counter(skills).most_common()

# %%
skills_df = pd.DataFrame(most_common_skills, columns=['Skill', 'Count'])

# %%
skills_df['Skill'] = skills_df['Skill'].str.upper()

# %%
grp_skills_df = skills_df.groupby('Skill').sum().nlargest(50, 'Count').reset_index()

# %%
grp_skills_df
# Out:
#                     Skill  Count
# 0                     SQL    440
# 1           DATA ANALYSIS    380
# 2            DATA ANALYST    328
# 3                  PYTHON    304
# 4          DATA ANALYTICS    168
# 5              ANALYTICAL    164
# 6               ANALYTICS    156
# 7         DATA MANAGEMENT    142
# 8                   EXCEL    123
# 9             DATA MINING    113
# 10           DATA QUALITY     96
# 11               POWER BI     95
# 12                TABLEAU     94
# 13        DATA COLLECTION     84
# 14  BUSINESS INTELLIGENCE     82
# 15     DATA VISUALIZATION     71
# 16       COMPUTER SCIENCE     65
# 17                    SAS     65
# 18       MACHINE LEARNING     64
# 19          DATA MODELING     58
# 20             MONITORING     58
# 21           DATA SCIENCE     56
# 22             MANAGEMENT     55
# 23             OPERATIONS     53
# 24         ADVANCED EXCEL     47
# 25      BUSINESS ANALYSIS     46
# 26    PROCESS IMPROVEMENT     44
# 27             AUTOMATION     43
# 28                  MYSQL     43
# 29                 MACROS     41
# 30              MS OFFICE     41
# 31     PROJECT MANAGEMENT     41
# 32             CONSULTING     39
# 33      ANALYTICAL SKILLS     38
# 34                    MIS     37
# 35            RECRUITMENT     36
# 36               BIG DATA     34
# 37                    CRM     31
# 38     FINANCIAL SERVICES     31
# 39             JAVASCRIPT     31
# 40            SQL QUERIES     31
# 41              MICROSOFT     30
# 42                  AGILE     29
# 43                 CODING     29
# 44             HEALTHCARE     29
# 45                      R     28
# 46             STATISTICS     28
# 47        DATA EXTRACTION     27
# 48        DATA VALIDATION     27
# 49       DATA WAREHOUSING     27

# %%
filtered_skills = grp_skills_df.drop(index=[1, 2, 4, 5, 6, 7, 14, 15, 16, 10, 13, 14, 15, 16, 19, 20, 21, 22, 23, 25, 26, 31, 32, 33])

# %%
plt.figure(figsize=(14, 8))
sns.barplot(data=filtered_skills[:10], x='Count', y='Skill', orient='h')
plt.title("Top 10 Most Common Skills in Job Postings");

# %%
plt.figure(figsize=(14, 7))
sns.countplot(data=df, y='location', order=df['location'].value_counts().head(10).index, orient='h')
plt.title("Top 10 Most Common Cities in Job Postings");
# plt.xticks(rotation=90);

# %%
plt.figure(figsize=(14, 7))
sns.countplot(data=df, y='company_name', order=df['company_name'].value_counts().head(10).index, orient='h')
plt.title("Top 10 Most Common Companies in Job Postings")
# plt.xticks(rotation=90);
plt.xlim(0, 25);
plt.ylabel('Company');

# %%
plt.figure(figsize=(14, 7))
sns.countplot(data=df, y='industry_type', order=df['industry_type'].value_counts().head(10).index, orient='h')
plt.title("Top 10 Most Common Industry Type in Job Postings")
# plt.xlim(0, 25);
plt.ylabel('Industry Type');

# %%
df['salary'].value_counts()
# Out:
# Not Disclosed                     855
# ₹ 15,00,000 - 30,00,000 P.A.        4
# ₹ 3,00,000 - 5,00,000 P.A.          4
# ₹ 15,00,000 - 27,50,000 P.A.        3
# ₹ 60,00,000 - 1,00,00,000 P.A.      3
#                                  ...
# ₹ 2,50,000 - 3,50,000 P.A.          1
# ₹ 3,00,000 - 4,50,000 P.A.          1
# ₹ 7,00,000 - 13,00,000 P.A.         1
# ₹ 7,00,000 - 9,00,000 P.A.          1
# ₹ 2,00,000 - 7,00,000 P.A.          1
# Name: salary, Length: 82, dtype: int64

# %%
# percentage of not disclosed. Most of job postings does not disclose salary
round(855/df.shape[0] * 100, 2)
# Out:
# 88.42

# %%
# almost all of the jobs are full time, permanent
df['employment_type'].value_counts()
# Out:
# Full Time, Permanent                958
# Full Time, Temporary/Contractual      9
# Name: employment_type, dtype: int64

# %%
plt.figure(figsize=(14, 7))
ax = sns.countplot(data=df, y='department', order=df['department'].value_counts().head(10).index, orient='h')
plt.title("Top 10 Most Common Departments in Job Postings")
# plt.xlim(0, 25);
plt.ylabel('Departments');

# %%
plt.figure(figsize=(14, 7))
ax = sns.countplot(data=df, y='role_category', order=df['role_category'].value_counts().head(10).index, orient='h')
plt.title("Top 10 Most Common Role Category in Job Postings")
# plt.xlim(0, 25);
plt.ylabel('Role Category');

# %%
education = df['education'].str.split(',')
education = [item.strip() for sublist in education for item in sublist]

most_common_education = Counter(education).most_common()

# %%
education_name = [elements[0] for elements in most_common_education][:10]
education_count = [elements[1] for elements in most_common_education][:10]
plt.figure(figsize=(14, 7))
ax = sns.barplot(y=education_name, x=education_count, orient='h')
plt.title("Top 10 Education Qualification in Job Postings")
# plt.xlim(0, 25);
plt.ylabel('Education');

# %%
# average number of openings 
# as you can see it does not make sense to have fractions in discrete data. Better option is to use median
df['num_openings'].mean()
# Out:
# 1.5482954545454546

# %%
# median number of openings
df['num_openings'].median()
# Out:
# 1.0

# %%
# company with highest number of opening
df.iloc[df['num_openings'].idxmax()]
# Out:
# job_title          EDP officer / Data Analyst | Jhunjhunun | Raja...
# company_name                                      RMW India Services
# experience                                               0 - 4 years
# salary                                    ₹ 3,00,000 - 5,00,000 P.A.
# location                                                  Chandrapur
# job_description    - Process various forms for admission, test re...
# role                                                    Data Analyst
# industry_type                                    E-Learning / EdTech
# department                                  Data Science & Analytics
# employment_type                                 Full Time, Permanent
# role_category                      Business Intelligence & Analytics
# education                                               Any Graduate
# key_skills         ['Advanced Excel', 'Report Preparation', 'Data...
# date_posted                                              18 days ago
# num_openings                                                    87.0
# num_applicants                                                   780
# experience_bins                                                  0-2
# Name: 863, dtype: object

# %%
# average number of applicants 
# as you can see it does not make sense to have fractions in discrete data. Better option is to use median and also 
# higher values skews the data, so mean is not the ideal choice here
df['num_applicants'].mean()
# Out:
# 838.6670113753878

# %%
# median number of applicants
df['num_applicants'].median()
# Out:
# 263.0

# %%
# company with highest number of applicants
df.iloc[df['num_applicants'].idxmax()]
# Out:
# job_title                                               Data Analyst
# company_name                                     Quickxpert Infotech
# experience                                               0 - 5 years
# salary                                                 Not Disclosed
# location                                                     Kolkata
# job_description    We have immediate openings for Data Analyst Tr...
# role                                                    Data Analyst
# industry_type                             Analytics / KPO / Research
# department                                  Data Science & Analytics
# employment_type                                 Full Time, Permanent
# role_category                      Business Intelligence & Analytics
# education                                               Any Graduate
# key_skills         ['SQL', 'python', 'C++', 'C', 'it', 'trainee',...
# date_posted                                              12 days ago
# num_openings                                                     5.0
# num_applicants                                                 83470
# experience_bins                                                  0-2
# Name: 108, dtype: object

# %%
# FUTURE
# do somethings with job_description data, it contains many information which will give useful insights
# scrape other job portals and compare/aggreate results from them.
